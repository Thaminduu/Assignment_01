# %%
import requests

def chat(prompt):
    response = requests.post(
        "http://localhost:11434/api/generate",
        json={
            "model": "llama3",
            "prompt": prompt,
            "stream": False
        }
    )
    return response.json()["response"]

print(chat("Explain machine learning in simple terms"))
# Out:
# Machine learning! It's a way for computers to learn and improve their performance on a task without being explicitly programmed. Here's a simplified explanation:
#
# **What is Machine Learning?**
#
# Machine learning is a type of artificial intelligence (AI) that allows computers to make decisions or predictions based on data. Instead of following strict rules, machines learn from examples and experiences.
#
# **How does it work?**
#
# Imagine you have a friend who loves playing poker. You want to help them become a better player by teaching the computer some basic strategies. Here's how:
#
# 1. **Data Collection**: You gather a large dataset of poker hands (e.g., 10,000 examples). Each hand includes information like cards played, bets made, and outcomes.
# 2. **Model Creation**: You create a machine learning model that can analyze this data and make predictions. Think of it as a "student" trying to learn the rules of poker.
# ...
